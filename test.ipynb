# %%
import pandas as pd

from matplotlib import pyplot as plt

predictions = {'age': 28, 'region': {'x': 269, 'y': 21, 'w': 64, 'h': 64}, 'gender': {'Woman': 1.1268730275332928, 'Man': 98.8731324672699}, 'dominant_gender': 'Man', 'race': {'asian': 0.004269475175533444, 'indian': 0.15436699613928795, 'black': 0.009731158206705004, 'white': 16.083891689777374, 'middle eastern': 83.21080803871155,
                                                                                                                                                                                'latino hispanic': 0.5369333084672689}, 'dominant_race': 'middle eastern', 'emotion': {'angry': 0.0027091933588963, 'disgust': 1.4913542401018276e-06, 'fear': 68.99976134300232, 'happy': 29.208293557167053, 'sad': 1.2900503352284431, 'surprise': 0.0009341824807052035, 'neutral': 0.49824798479676247}, 'dominant_emotion': 'fear'}

df = pd.DataFrame(predictions)

print(predictions)

# Acesse a coluna 'gender' do DataFrame
gender_data = df['gender']

# Acesse o valor associado à chave 'Woman' no dicionário
woman_percentage = gender_data['Woman']

# Acesse o valor associado à chave 'Man' no dicionário
man_percentage = gender_data['Man']

""" # Exiba os valores
print("Woman Percentage:", woman_percentage)
print("Man Percentage:", man_percentage)

# Determine qual gênero é dominante
if man_percentage > woman_percentage:
    print('O gênero dominante é Man')
else:
    print('O gênero dominante é Woman') """

# Dados para o gráfico de pizza
labels = ['Mulher', 'Homem']
sizes = [woman_percentage, man_percentage]
colors = ['pink', 'lightsteelblue']
explode = (0.1, 0)  # Explodir a primeira fatia (Mulher)

# Crie um gráfico de pizza
plt.pie(sizes, explode=explode, labels=labels, colors=colors, autopct='%1.1f%%',
        shadow=True, startangle=140, pctdistance=0.85, wedgeprops={'edgecolor': 'black'})
# sizes - Valores numéricos das fatias
# explode - Define quais fatias serão explodidas
# labels - Rótulos das fatias
# colors - Cores das fatias
# autopct - Formato de exibição dos valores numéricos
# shadow - Ativa sombra
# startangle - Define o ângulo inicial de exibição das fatias
# pctdistance - Define a distância dos valores numéricos em relação ao centro do gráfico
# wedgeprops - Define as propriedades das fatias (borda)

plt.axis('equal')  # Assegura que o gráfico de pizza seja um círculo.

# Adicionar o tight_layout para ajustar automaticamente o padding em torno do gráfico
# plt.tight_layout()

""" # Desenhar círculo para gráfico de pizza
circle = plt.Circle((0, 0), 0.7, fc='white')
plt.gca().add_artist(circle) """

plt.title('Porcentagem de Gênero') # Define o título do gráfico

plt.show() # Exibe o gráfico
# Out:
# {'age': 28, 'region': {'x': 269, 'y': 21, 'w': 64, 'h': 64}, 'gender': {'Woman': 1.1268730275332928, 'Man': 98.8731324672699}, 'dominant_gender': 'Man', 'race': {'asian': 0.004269475175533444, 'indian': 0.15436699613928795, 'black': 0.009731158206705004, 'white': 16.083891689777374, 'middle eastern': 83.21080803871155, 'latino hispanic': 0.5369333084672689}, 'dominant_race': 'middle eastern', 'emotion': {'angry': 0.0027091933588963, 'disgust': 1.4913542401018276e-06, 'fear': 68.99976134300232, 'happy': 29.208293557167053, 'sad': 1.2900503352284431, 'surprise': 0.0009341824807052035, 'neutral': 0.49824798479676247}, 'dominant_emotion': 'fear'}
